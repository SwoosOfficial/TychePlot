# %%
import sys
import os
sys.path.append("../Calculator/")
from Filereader import fileToNpArray
import matplotlib.pyplot as plt

# %%
filename=

# %%
sepList=["\t",",",";"]

# %%
for sep in sepList:
    for n in range(0,200):
        try:
            data=fileToNpArray(filename, separator=sep, skiplines=n)
            break
        except:
            pass

# %%
for x in range(len(data[0]))
    plt.plot(data[::0],data::x)
plt.show()
