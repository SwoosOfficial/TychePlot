# %%
import os
from multiprocessing import Pool

# %%
class MultiPlot:
    
    def __plotPair(plotpair):
        return [plot.doPlot() for plot in plotpair]

    def __plotListProc(plotList):
        return pool.map(plotPair,plotList)

    def __init__(self, plotList):
        self.plotList=plotList
        self.pool = Pool(os.cpu_count()) # Multicore
        self.files = []
    
    def getFiles(self):
        if files == []:
            self.files=self.__plotListProc(self.plotList)
        return self.files
