# %%
import sys
import numpy as np
import scipy.interpolate as sci
sys.path.append("../../../Projects/TychePlot/")para_1_interp_data=para_interp(wavelengths).T
from Filereader import fileToNpArray,npArrayToFile

# %%
import os
os.listdir()
# Out:
# ['FiletoSp.ipynb',
#  'FilestoNk-EMA.ipynb',
#  'FiletoNk.ipynb',
#  '.ipynb_checkpoints',
#  'FiletoTSV.ipynb']

# %%
name="TCTA:MoOx"
file_1_para="tcta-kim2013.nk"
file_1_perp=""
file_2_para="MoOx.nk"
file_2_perp=""
EMA_ratio=0.5

# %%
wavelengths=np.arange(300,801,1)

# %%
read_options={
                "separator":"\t",
            }
write_options={
                "separator":"\t",
                "fileEnding":".nk",
                "skiplines":0
            }

# %%
para_1_array=fileToNpArray(file_1_para, **read_options)[0]
para_2_array=fileToNpArray(file_2_para, **read_options)[0]
para_1_interp=sci.interp1d(para_array[:,0],para_array[:,1:3], axis=0)
para_2_interp=sci.interp1d(para_array[:,0],para_array[:,1:3], axis=0)
para_1_interp_data=para_interp(wavelengths).T
para_2_interp_data=para_interp(wavelengths).T
if file_1_perp == "":
    double_EMA_data=EMA_ratio*para_1_interp_data+(1-EMA_ratio)*para_2_interp_data
    EMA_data=double_EMA_data/2
    new_array_data=np.vstack((wavelengths.T,EMA_data)).T
    write_options["preString"]="",
else:    
    perp_array=fileToNpArray(file_perp, **read_options)[0]
    perp_interp=sci.interp1d(para_array[:,0],para_array[:,1:3], axis=0)
    perp_interp_data=perp_interp(wavelengths).T
    new_array_data=np.vstack((wavelengths.T,para_interp_data,perp_interp_data)).T
    write_options["preString"]="bir\n",
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-7f60f0863f95> in <module>
# ----> 1 para_1_array=fileToNpArray(file_1_para, **read_options)[0]
#       2 para_2_array=fileToNpArray(file_2_para, **read_options)[0]
#       3 para_1_interp=sci.interp1d(para_array[:,0],para_array[:,1:3], axis=0)
#       4 para_2_interp=sci.interp1d(para_array[:,0],para_array[:,1:3], axis=0)
#       5 para_1_interp_data=para_interp(wavelengths).T
#
# ~/Projects/TychePlot/Filereader.py in fileToNpArray(filename, separator, skiplines, backoffset, lastlines, exceptColumns, commaToPoint, lastlineNoNewLine, fileEnding, transpose, ignoreRowCol, debug)
#      11 def fileToNpArray(filename, separator=",", skiplines=1, backoffset=0, lastlines=0, exceptColumns=[], commaToPoint=False, lastlineNoNewLine=False, fileEnding=None, transpose=False, ignoreRowCol=None, debug=False):
# ...

# %%
npArrayToFile(name,new_array_data,**write_options)
