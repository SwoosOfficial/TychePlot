# %%
import sys
import numpy as np
import scipy.interpolate as sci
from functools import wraps
sys.path.append("../../TychePlot/")
from Filereader import fileToNpArray,npArrayToFile

# %%
name="20200701_Recalibration_GigahertzOptics_365-1800nm.dat"
file_spectrum="20200701_Recalibration_GigahertzOptics_365-1800nm.dat"

# %%
read_options={
                "separator":"\t",
                "skiplines":2
            }
write_options={
                "separator":"\t",
                "skiplines":0,
                "fileEnding":".tsv"
            }

# %%
spectrum_array=fileToNpArray(file_spectrum, **read_options)[0]

# %%
npArrayToFile(name,spectrum_array,**write_options)
