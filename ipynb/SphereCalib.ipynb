# %%
import sys
import os
sys.path.append("../../TychePlot/")
from SpectraPlot import SpectraPlot
from Filereader import fileToNpArray,npArrayToFile
import numpy as np

# %%
def circle_area(radius):
    return radius**2*np.pi

def steradian_by_diameter_and_distance(distance, diameter_hole):
    theta=np.arctan(diameter_hole/(2*distance))
    #A=r**2*Int_0^pi Int_0^2pi sin(theta) d_theta d_phi
    return 2*np.pi*(1-np.cos(theta))

# %%
## Static Lamp parameters

lamp_on_top_file_high_intens='calib/130mm_6s_100rep'
lamp_on_fiber_high_intens='calib/fiber_30s_100rep'
lamp_on_top_file='calib/130mm_400ms_100rep'
lamp_on_fiber='calib/fiber_4s_100rep'
lamp_calib_file='calib/20200701_Recalibration_GigahertzOptics_365-1800nm'

## Sample Holder
lamp_with_fiber_SH_high_intens='calib/SH_soln_30s_10rep'
lamp_with_fiber_SH='calib/SH_soln_4s_10rep'
# Output
SH_calib_filename='calib/SH_soln_calib'

# %%
fiber_diameter=550*10**-6 #m
lamp_hole_diameter=10*10**-3 #m
sphere_hole_diameter=20*10**-3 #m
sphere_lamp_distance=132.5*10**-3 #m


exp_time_lamp_on_top_high_intens=6 #s
exp_time_lamp_on_fiber_high_intens=30 #s
exp_time_SH_high_intens=30 #s
repetitions_lamp_on_top_high_intens=100 #
repetitions_lamp_on_fiber_high_intens=100 #
repetitions_SH_high_intens=10 #
exp_time_lamp_on_top=0.4#s
exp_time_lamp_on_fiber=4 #s
exp_time_SH=4 #s
repetitions_lamp_on_top=100 #s
repetitions_lamp_on_fiber=100 #s
repetitions_SH=10 #s

error_per_channel=0.1 #percent
stiching_wavelength=440*10**-9

# %%
file_format={
                "skiplines":1,
                "fileEnding":".tsv",
                "separator":"\t",
                "commaToPoint":True,
            }
calib_format={
                "skiplines":2,
                "fileEnding":".dat",
                "separator":"\t",
            }
SH_calib_format={
                "preSting":"Wavelengths (m)\tSpectral Radiant Flux (W/nm)",
                "separator":"\t",
                "fileEnding":".clbr",
}

# %%
lamp_on_top_high_intens=fileToNpArray(lamp_on_top_file_high_intens, **file_format)[0]
lamp_on_fiber_high_intens=fileToNpArray(lamp_on_fiber_high_intens, **file_format)[0]
SH_high_intens=fileToNpArray(lamp_with_fiber_SH_high_intens, **file_format)[0]
lamp_on_top=fileToNpArray(lamp_on_top_file, **file_format)[0]
lamp_on_fiber=fileToNpArray(lamp_on_fiber, **file_format)[0]
SH=fileToNpArray(lamp_with_fiber_SH, **file_format)[0]
lamp_calib=fileToNpArray(lamp_calib_file, **calib_format)[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-125a28de1c2f> in <module>
# ----> 1 lamp_on_top_high_intens=fileToNpArray(lamp_on_top_file_high_intens, **file_format)[0]
#       2 lamp_on_fiber_high_intens=fileToNpArray(lamp_on_fiber_high_intens, **file_format)[0]
#       3 SH_high_intens=fileToNpArray(lamp_with_fiber_SH_high_intens, **file_format)[0]
#       4 lamp_on_top=fileToNpArray(lamp_on_top_file, **file_format)[0]
#       5 lamp_on_fiber=fileToNpArray(lamp_on_fiber, **file_format)[0]
#
# ~\Documents\TychePlot\Filereader.py in fileToNpArray(filename, separator, skiplines, backoffset, lastlines, exceptColumns, commaToPoint, lastlineNoNewLine, fileEnding, transpose, ignoreRowCol, debug)
#      13         file = open(filename,"r")
#      14     else:
# ---> 15         file = open(filename+fileEnding,"r")
#      16     lines = file.readlines()
#      17     if lastlines != 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'calib/130mm_6s_100rep.tsv'

# %%
lamp_on_top_counts_per_second=lamp_on_top[:,1]/(exp_time_lamp_on_top*repetitions_lamp_on_top)
lamp_on_fiber_counts_per_second=lamp_on_fiber[:,1]/(exp_time_lamp_on_fiber*repetitions_lamp_on_fiber)
SH_counts_per_second=SH[:,1]/(exp_time_SH*repetitions_SH)
lamp_on_top_high_intens_counts_per_second=lamp_on_top_high_intens[:,1]/(exp_time_lamp_on_top_high_intens*repetitions_lamp_on_top_high_intens)
lamp_on_fiber_high_intens_counts_per_second=lamp_on_fiber_high_intens[:,1]/(exp_time_lamp_on_fiber_high_intens*repetitions_lamp_on_fiber_high_intens)
SH_high_intens_counts_per_second=SH_high_intens[:,1]/(exp_time_SH_high_intens*repetitions_SH_high_intens)
wavelengths=lamp_on_top[:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6af24f15080a> in <module>
# ----> 1 lamp_on_top_counts_per_second=lamp_on_top[:,1]/(exp_time_lamp_on_top*repetitions_lamp_on_top)
#       2 lamp_on_fiber_counts_per_second=lamp_on_fiber[:,1]/(exp_time_lamp_on_fiber*repetitions_lamp_on_fiber)
#       3 SH_counts_per_second=SH[:,1]/(exp_time_SH*repetitions_SH)
#       4 lamp_on_top_high_intens_counts_per_second=lamp_on_top_high_intens[:,1]/(exp_time_lamp_on_top_high_intens*repetitions_lamp_on_top_high_intens)
#       5 lamp_on_fiber_high_intens_counts_per_second=lamp_on_fiber_high_intens[:,1]/(exp_time_lamp_on_fiber_high_intens*repetitions_lamp_on_fiber_high_intens)
#
# NameError: name 'lamp_on_top' is not defined

# %%
lamp_calib[:,0]=lamp_calib[:,0]*10**-9
lamp_calib_func=SpectraPlot.lum_interpolator(lamp_calib.T, kind="cubic")
lamp_calib_W_per_sr_sqm_nm=lamp_calib_func(wavelengths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7610de812e8f> in <module>
# ----> 1 lamp_calib[:,0]=lamp_calib[:,0]*10**-9
#       2 lamp_calib_func=SpectraPlot.lum_interpolator(lamp_calib.T, kind="cubic")
#       3 lamp_calib_W_per_sr_sqm_nm=lamp_calib_func(wavelengths)
#
# NameError: name 'lamp_calib' is not defined

# %%
lamp_calib_on_fiber_W_per_nm=lamp_calib_W_per_sr_sqm_nm*2*np.pi*circle_area(fiber_diameter/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9883a163ec5c> in <module>
# ----> 1 lamp_calib_on_fiber_W_per_nm=lamp_calib_W_per_sr_sqm_nm*2*np.pi*circle_area(fiber_diameter/2)
#
# NameError: name 'lamp_calib_W_per_sr_sqm_nm' is not defined

# %%
lamp_calib_on_top_W_per_nm_sqm=lamp_calib_W_per_sr_sqm_nm*steradian_by_diameter_and_distance(sphere_lamp_distance, sphere_hole_diameter)
lamp_calib_on_top_W_per_nm=lamp_calib_on_top_W_per_nm_sqm*circle_area(lamp_hole_diameter/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-893f7ec13548> in <module>
# ----> 1 lamp_calib_on_top_W_per_nm_sqm=lamp_calib_W_per_sr_sqm_nm*steradian_by_diameter_and_distance(sphere_lamp_distance, sphere_hole_diameter)
#       2 lamp_calib_on_top_W_per_nm=lamp_calib_on_top_W_per_nm_sqm*circle_area(lamp_hole_diameter/2)
#
# NameError: name 'lamp_calib_W_per_sr_sqm_nm' is not defined

# %%
# W_per_nm / counts_per_s_nm = J/count
calib_on_fiber_J_per_count=lamp_calib_on_fiber_W_per_nm/lamp_on_fiber_counts_per_second
calib_on_top_J_per_count=lamp_calib_on_top_W_per_nm/lamp_on_top_counts_per_second
calib_on_fiber_high_intens_J_per_count=lamp_calib_on_fiber_W_per_nm/lamp_on_fiber_high_intens_counts_per_second
calib_on_top_high_intens_J_per_count=lamp_calib_on_top_W_per_nm/lamp_on_top_high_intens_counts_per_second
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-217d8689070d> in <module>
#       1 # W_per_nm / counts_per_s_nm = J/count
# ----> 2 calib_on_fiber_J_per_count=lamp_calib_on_fiber_W_per_nm/lamp_on_fiber_counts_per_second
#       3 calib_on_top_J_per_count=lamp_calib_on_top_W_per_nm/lamp_on_top_counts_per_second
#       4 calib_on_fiber_high_intens_J_per_count=lamp_calib_on_fiber_W_per_nm/lamp_on_fiber_high_intens_counts_per_second
#       5 calib_on_top_high_intens_J_per_count=lamp_calib_on_top_W_per_nm/lamp_on_top_high_intens_counts_per_second
#
# NameError: name 'lamp_calib_on_fiber_W_per_nm' is not defined

# %%
import scipy.interpolate as sci
import scipy.integrate as scin
import matplotlib.pyplot as plt
plt.plot(wavelengths, calib_on_fiber_J_per_count, wavelengths, calib_on_top_J_per_count, wavelengths, calib_on_fiber_high_intens_J_per_count, wavelengths, calib_on_top_high_intens_J_per_count)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2c0ed3473963> in <module>
#       2 import scipy.integrate as scin
#       3 import matplotlib.pyplot as plt
# ----> 4 plt.plot(wavelengths, calib_on_fiber_J_per_count, wavelengths, calib_on_top_J_per_count, wavelengths, calib_on_fiber_high_intens_J_per_count, wavelengths, calib_on_top_high_intens_J_per_count)
#       5 #plt.ylim(10**-,10**3)
#       6 plt.yscale("log")
#
# NameError: name 'wavelengths' is not defined

# %%
plt.clf()
plt.plot(wavelengths, lamp_on_fiber_counts_per_second, wavelengths, lamp_on_top_counts_per_second, wavelengths, lamp_on_fiber_high_intens_counts_per_second, wavelengths, lamp_on_top_high_intens_counts_per_second)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5f34a24225c2> in <module>
#       1 plt.clf()
# ----> 2 plt.plot(wavelengths, lamp_on_fiber_counts_per_second, wavelengths, lamp_on_top_counts_per_second, wavelengths, lamp_on_fiber_high_intens_counts_per_second, wavelengths, lamp_on_top_high_intens_counts_per_second)
#       3 #plt.ylim(10**-,10**3)
#       4 plt.yscale("log")
#
# NameError: name 'wavelengths' is not defined

# %%
plt.clf()
plt.plot(wavelengths, calib_on_fiber_J_per_count/calib_on_top_J_per_count, wavelengths, calib_on_fiber_high_intens_J_per_count/calib_on_top_high_intens_J_per_count)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bc2630530c8a> in <module>
#       1 plt.clf()
# ----> 2 plt.plot(wavelengths, calib_on_fiber_J_per_count/calib_on_top_J_per_count, wavelengths, calib_on_fiber_high_intens_J_per_count/calib_on_top_high_intens_J_per_count)
#       3 #plt.ylim(10**-,10**3)
#       4 plt.yscale("log")
#
# NameError: name 'wavelengths' is not defined

# %%
stiching_index=np.argwhere(wavelengths > stiching_wavelength)[0][0]
lowest_valid_calib_index=np.argwhere(wavelengths > lamp_calib[0][0])[0][0]
wavelengths_cropped=wavelengths[lowest_valid_calib_index:]
stiched_calib_on_fiber_J_per_count=np.hstack((calib_on_fiber_high_intens_J_per_count[lowest_valid_calib_index:stiching_index],calib_on_fiber_J_per_count[stiching_index:]))
stiched_calib_on_top_J_per_count=np.hstack((calib_on_top_high_intens_J_per_count[lowest_valid_calib_index:stiching_index],calib_on_top_J_per_count[stiching_index:]))
stiched_lamp_on_fiber_counts_per_second=np.hstack((lamp_on_fiber_high_intens_counts_per_second[lowest_valid_calib_index:stiching_index],lamp_on_fiber_counts_per_second[stiching_index:]))
stiched_lamp_on_top_counts_per_second=np.hstack((lamp_on_top_high_intens_counts_per_second[lowest_valid_calib_index:stiching_index],lamp_on_top_counts_per_second[stiching_index:]))
stiched_SH_counts_per_second=np.hstack((SH_high_intens_counts_per_second[lowest_valid_calib_index:stiching_index],SH_counts_per_second[stiching_index:]))
# calib_spec= C * meas_spec
# calib_spec_on_top= C_KC * lamp_on_top_spec
# calib_spec_on_fiber= C_KFC * lamp_on_fiber_spec
#
# with that:
#
# calib_spec_on_fiber= C_KFC * lamp_on_fiber_spec
# calib_spec_on_fiber= C_F * C_KC * lamp_on_fiber_spec
# calib_spec_on_fiber= C_F * C_KC * lamp_on_fiber_spec
# C_F=calib_spec_on_fiber/(C_KC*lamp_on_fiber_spec)
# fiber_calib_spec=C_KC*lamp_on_fiber_spec
# 
# real_spec= C_SH * C_KC * meas_spec
# C_SH = fiber_calib_spec / (C_KC * meas_spec)

C_F=lamp_calib_on_fiber_W_per_nm[lowest_valid_calib_index:]/(stiched_lamp_on_fiber_counts_per_second*stiched_calib_on_top_J_per_count)
C_KC=stiched_calib_on_top_J_per_count
C_KFC=stiched_calib_on_fiber_J_per_count
calib_spec_after_fiber=C_KC*stiched_lamp_on_fiber_counts_per_second
C_SH=calib_spec_after_fiber/(C_KC*stiched_SH_counts_per_second)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-904eca973d35> in <module>
# ----> 1 stiching_index=np.argwhere(wavelengths > stiching_wavelength)[0][0]
#       2 lowest_valid_calib_index=np.argwhere(wavelengths > lamp_calib[0][0])[0][0]
#       3 wavelengths_cropped=wavelengths[lowest_valid_calib_index:]
#       4 stiched_calib_on_fiber_J_per_count=np.hstack((calib_on_fiber_high_intens_J_per_count[lowest_valid_calib_index:stiching_index],calib_on_fiber_J_per_count[stiching_index:]))
#       5 stiched_calib_on_top_J_per_count=np.hstack((calib_on_top_high_intens_J_per_count[lowest_valid_calib_index:stiching_index],calib_on_top_J_per_count[stiching_index:]))
#
# NameError: name 'wavelengths' is not defined

# %%
plt.plot(wavelengths_cropped,stiched_calib_on_fiber_J_per_count , wavelengths_cropped, stiched_calib_on_top_J_per_count)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6cc628fc7a02> in <module>
# ----> 1 plt.plot(wavelengths_cropped,stiched_calib_on_fiber_J_per_count , wavelengths_cropped, stiched_calib_on_top_J_per_count)
#       2 #plt.ylim(10**-,10**3)
#       3 plt.yscale("log")
#
# NameError: name 'wavelengths_cropped' is not defined

# %%
plt.plot(wavelengths_cropped,lamp_calib_on_fiber_W_per_nm[lowest_valid_calib_index:], wavelengths_cropped, lamp_calib_on_top_W_per_nm[lowest_valid_calib_index:])
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a7a999e75e33> in <module>
# ----> 1 plt.plot(wavelengths_cropped,lamp_calib_on_fiber_W_per_nm[lowest_valid_calib_index:], wavelengths_cropped, lamp_calib_on_top_W_per_nm[lowest_valid_calib_index:])
#       2 #plt.ylim(10**-,10**3)
#       3 plt.yscale("log")
#
# NameError: name 'wavelengths_cropped' is not defined

# %%
plt.clf()
plt.plot(wavelengths_cropped, stiched_lamp_on_fiber_counts_per_second, wavelengths_cropped, stiched_lamp_on_top_counts_per_second)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5da8400c6ea9> in <module>
#       1 plt.clf()
# ----> 2 plt.plot(wavelengths_cropped, stiched_lamp_on_fiber_counts_per_second, wavelengths_cropped, stiched_lamp_on_top_counts_per_second)
#       3 #plt.ylim(10**-,10**3)
#       4 plt.yscale("log")
#
# NameError: name 'wavelengths_cropped' is not defined

# %%
plt.clf()
#interpolate_calibration
SH_calib_interpol=SpectraPlot.lum_interpolator((wavelengths_cropped,C_SH*C_KC), kind='cubic')
SH_calib_full=SH_calib_interpol(wavelengths)
plt.plot(wavelengths_cropped, C_SH*C_KC, wavelengths, SH_calib_full)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f63101af815a> in <module>
#       1 plt.clf()
#       2 #interpolate_calibration
# ----> 3 SH_calib_interpol=SpectraPlot.lum_interpolator((wavelengths_cropped,C_SH*C_KC), kind='cubic')
#       4 SH_calib_full=SH_calib_interpol(wavelengths)
#       5 plt.plot(wavelengths_cropped, C_SH*C_KC, wavelengths, SH_calib_full)
#
# NameError: name 'wavelengths_cropped' is not defined

# %%
plt.clf()
plt.plot(wavelengths_cropped, C_KC*stiched_SH_counts_per_second)
#plt.ylim(10**-,10**3)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9974d7abc11e> in <module>
#       1 plt.clf()
# ----> 2 plt.plot(wavelengths_cropped, C_KC*stiched_SH_counts_per_second)
#       3 #plt.ylim(10**-,10**3)
#       4 plt.yscale("log")
#
# NameError: name 'wavelengths_cropped' is not defined

# %%
fiber_flux_func=sci.interp1d(wavelengths_cropped,stiched_lamp_on_fiber_counts_per_second*stiched_calib_on_top_J_per_count, kind='cubic')
# Integration
fiber_total_flux=scin.quad(fiber_flux_func,wavelengths_cropped[0],wavelengths_cropped[-1])
fiber_total_flux[0]*10**9
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c07eb40063fd> in <module>
# ----> 1 fiber_flux_func=sci.interp1d(wavelengths_cropped,stiched_lamp_on_fiber_counts_per_second*stiched_calib_on_top_J_per_count, kind='cubic')
#       2 # Integration
#       3 fiber_total_flux=scin.quad(fiber_flux_func,wavelengths_cropped[0],wavelengths_cropped[-1])
#       4 fiber_total_flux[0]*10**9
#
# NameError: name 'wavelengths_cropped' is not defined

# %%
npArrayToFile(SH_calib_filename,np.vstack((wavelengths,SH_calib_full)).T,**SH_calib_format)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-5005e69ee795> in <module>
# ----> 1 npArrayToFile(SH_calib_filename,np.vstack((wavelengths,SH_calib_full)).T,**SH_calib_format)
#
# NameError: name 'wavelengths' is not defined

# %%
lamp_calib
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-80a8dec7c63b> in <module>
# ----> 1 lamp_calib
#
# NameError: name 'lamp_calib' is not defined
