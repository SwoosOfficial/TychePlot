# %%
import sys
sys.path.append("../Calculator_V2/")
from angMeas.AngularMeasurement import *

# %%
filename="OSRAM_sample_5_3V_180muA.txt"
filename2="CsPbBrgitter1-9_15_onV2.txt"

# %%
PlotMeasurement(filename, wavelength=690, savepath="osram.3V")
# Out:
# osram
# 3V

# %%
PlotMeasurement(filename2, wavelength=513)

# %%
PlotSpectrum(filename, angle=180)
# Out:
# /home/tassilo/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
