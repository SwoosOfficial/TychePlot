# %%
import sys
sys.path.append("../Calculator/")
from OLEDPlot import OLEDCustomFileListPlot

# %%
#obligatory
spectraPath=("JETI/XXXX_A_12V.csv","JETI/XXXX_B_12V.csv","JETI/XXXX_C_12V.csv","JETI/XXXX_G_12V.csv")
name="XXXX"
fileList=[["XXXX_A_1","XXXX_A_2","XXXX_A_3","XXXX_A_4"],
         ["XXXX_B_1","XXXX_B_2","XXXX_B_3","XXXX_B_4"],
         ["XXXX_C_1","XXXX_C_3","XXXX_C_4"],
         ["XXXX_G_1","XXXX_G_2","XXXX_G_3","XXXX_G_4"]]
labelList=["Thick CsPbBr3","Thin CsPbBr3","CsPbBr3 with PVK","Ir(ppy)3 with PVK"]
sclu=["",
      "Voltage (V)",
      "Current (A)",
      "Current Density (mA/cm^2)",
      "Luminance (cd/m^2)",
      "Radiance (W/(sr*m^2))",
      "Current Efficiency (cd/A)",
      "Luminous Efficacy (lm/W)",
      "EQE (%)"
     ]

# %%
inputParameters={
                    "spectraFile":spectraPath,
                    "labels":labelList,
                    "noSweepBackMeasured":False,
                    "showColLabelUnit":sclu
                }

# %%
plot=OLEDCustomFileListPlot(fileList,
                            name, 
                            **inputParameters)

# %%
expect,err=plot.processAllAndExport()
